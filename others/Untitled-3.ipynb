# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import missingno as msno

df = pd.read_csv("C:/Users/AYACDA23/Desktop/pervol.csv", encoding="latin-1")

df.head()
# Out:
#         FECHA  TURNO            ID JEFE DE GUARDIA  \
# 0  30/12/2018    dia      vn560-7e    Jaime Santos
# 1  30/12/2018    dia       cx526ne    Jaime Santos
# 2  30/12/2018    dia  rp100(-)4540    Jaime Santos
# 3  30/12/2018    dia       cx890ne    Jaime Santos
# 4  30/12/2018  noche      vn560-7e    luis aguilar
#
#   REPORTE DEL DISPARO POR GUARDIA FECHA DE DISPARO         LABOR  NIVEL  \
# 0                               B       30/12/2018    VN 560-7-E   4560
# 1                               B       30/12/2018     CX 526 NE   4540
# 2                               B       30/12/2018  RP100(-)4540   4540
# 3                               B       30/12/2018     CX 890 NE   4840
# 4                               C       30/12/2018    VN 560-7-E   4560
#
#           FASE  SECCIÓN  ...  KG DE EXPLOSIVO ACCESORIOS CORDON DETONANTE  \
# 0  Preparación  3.5x3.5  ...        67.102856         36               65
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1891 entries, 0 to 1890
# Data columns (total 84 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   FECHA                            1891 non-null   object
#  1   TURNO                            1891 non-null   object
#  2   ID                               1891 non-null   object
#  3   JEFE DE GUARDIA                  1891 non-null   object
#  4   REPORTE DEL DISPARO POR GUARDIA  1890 non-null   object
#  5   FECHA DE DISPARO                 1891 non-null   object
#  6   LABOR                            1891 non-null   object
#  7   NIVEL                            1891 non-null   int64
#  8   FASE                             1891 non-null   object
#  9   SECCIÓN                          1891 non-null   object
#  10  BARRA FT                         1355 non-null   float64
#  11  REPORTE DE DISPARO               1891 non-null   object
# ...

# %%
msno.matrix(df)
# Out:
# <Axes: >
